# %% [markdown]
# Вариант 1
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы получаем должность) с сайтов HH(обязательно) и/или Superjob(по желанию). Приложение должно анализировать несколько страниц сайта (также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     1. Наименование вакансии.
#     2. Предлагаемую зарплату (разносим в три поля: минимальная и максимальная и валюта. цифры        преобразуем к цифрам).
#     3.  Ссылку на саму вакансию.
#     4. Сайт, откуда собрана вакансия.
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas. Сохраните в json либо csv.

# %%
import requests
import lxml
from lxml import html
from bs4 import BeautifulSoup
import pandas as pd

pages = [1, 2, 3, 4, 5]
query = input('Enter the title: ').replace(' ', '+')
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/110.0'}
result_data = []


for page in pages:
    url = f'https://spb.hh.ru/search/vacancy?text={query}&page=1'
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, 'lxml')
    all_div_vacancy = soup.find_all('div', class_='vacancy-serp-item-body__main-info')
    for div in all_div_vacancy:
        vacancy_data = []
        vacancy_data.append(div.find('a', class_='serp-item__title').get('href'))
        vacancy_data.append(div.find('a', class_='serp-item__title').contents[0])
        vacancy_data.append('https://spb.hh.ru/')
        try:
            vacancy_data.append(''.join(div.find('a', class_='bloko-link bloko-link_kind-tertiary').contents))
        except:
            vacancy_data.append(' ')
        try:
            vacancy_data.append(''.join(div.find('span', class_='bloko-header-section-3').contents))
        except:
            vacancy_data.append(' ')
        result_data.append(vacancy_data)
    
for el in result_data:
    for _ in el:
        print(_)
    print('-------------------------------------------------------------')
# Out:
# Enter the title: python
# https://spb.hh.ru/vacancy/77197403?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# SberTech
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76141435?from=vacancy_search_list&query=python
# Python Data Engineer (junior)
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/75719539?from=vacancy_search_list&query=python
# Программист Python (middle)
# https://spb.hh.ru/
# Pentestit
# 70 000 – 105 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77020122?from=vacancy_search_list&query=python
# Python (Django) Backend developer
# https://spb.hh.ru/
# evrone.ru
# до  400 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/71259333?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# ООО  Новые Системы
# 100 000 – 100 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76447915?from=vacancy_search_list&query=python
# Разработчик (Backend developer / Python)
# https://spb.hh.ru/
# ООО  Статус
# от  100 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77280737?from=vacancy_search_list&query=python
# Middle Python разработчик/Руководитель группы
# https://spb.hh.ru/
# ООО  Точка Зрения
# 110 000 – 160 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77324689?from=vacancy_search_list&query=python
# Python Developer
# https://spb.hh.ru/
# ООО  КомплИТех
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77284919?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# Holyweb
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77315663?from=vacancy_search_list&query=python
# Программист Python
# https://spb.hh.ru/
# ООО  WaveAccess
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77294601?from=vacancy_search_list&query=python
# Python Developer (Backend)
# https://spb.hh.ru/
# Samsung Research Russia
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77179552?from=vacancy_search_list&query=python
# Senior Python разработчик
# https://spb.hh.ru/
# ООО  24 часа ТВ
# от  300 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77244580?from=vacancy_search_list&query=python
# Python developer (remote)
# https://spb.hh.ru/
# LATOKEN
# от  1 000   USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76826004?from=vacancy_search_list&query=python
# Программист Python (Django)
# https://spb.hh.ru/
# Enjoypro
# 160 000 – 180 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76354970?from=vacancy_search_list&query=python
# Data Analyst
# https://spb.hh.ru/
# ООО  Б-рейн Тех
# 2 000 – 5 000  USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77329747?from=vacancy_search_list&query=python
# Data engineer (middle+)
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# до  350 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77193793?from=vacancy_search_list&query=python
# Python-разработчик
# https://spb.hh.ru/
# Тинькофф
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76921562?from=vacancy_search_list&query=python
# Data-engeneer (Middle)
# https://spb.hh.ru/
# Платформа Больших Данных
# 250 000 – 300 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76925483?from=vacancy_search_list&query=python
# Data Scientist
# https://spb.hh.ru/
# 7RedLines
# 160 000 – 200 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77208642?from=vacancy_search_list&query=python
# Data Scientist middle+/Senior
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# 250 000 – 350 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77197403?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# SberTech
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76141435?from=vacancy_search_list&query=python
# Python Data Engineer (junior)
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/75719539?from=vacancy_search_list&query=python
# Программист Python (middle)
# https://spb.hh.ru/
# Pentestit
# 70 000 – 105 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77020122?from=vacancy_search_list&query=python
# Python (Django) Backend developer
# https://spb.hh.ru/
# evrone.ru
# до  400 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/71259333?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# ООО  Новые Системы
# 100 000 – 100 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76447915?from=vacancy_search_list&query=python
# Разработчик (Backend developer / Python)
# https://spb.hh.ru/
# ООО  Статус
# от  100 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77280737?from=vacancy_search_list&query=python
# Middle Python разработчик/Руководитель группы
# https://spb.hh.ru/
# ООО  Точка Зрения
# 110 000 – 160 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77324689?from=vacancy_search_list&query=python
# Python Developer
# https://spb.hh.ru/
# ООО  КомплИТех
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77284919?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# Holyweb
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77315663?from=vacancy_search_list&query=python
# Программист Python
# https://spb.hh.ru/
# ООО  WaveAccess
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77294601?from=vacancy_search_list&query=python
# Python Developer (Backend)
# https://spb.hh.ru/
# Samsung Research Russia
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77179552?from=vacancy_search_list&query=python
# Senior Python разработчик
# https://spb.hh.ru/
# ООО  24 часа ТВ
# от  300 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77244580?from=vacancy_search_list&query=python
# Python developer (remote)
# https://spb.hh.ru/
# LATOKEN
# от  1 000   USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76826004?from=vacancy_search_list&query=python
# Программист Python (Django)
# https://spb.hh.ru/
# Enjoypro
# 160 000 – 180 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76354970?from=vacancy_search_list&query=python
# Data Analyst
# https://spb.hh.ru/
# ООО  Б-рейн Тех
# 2 000 – 5 000  USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77329747?from=vacancy_search_list&query=python
# Data engineer (middle+)
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# до  350 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77193793?from=vacancy_search_list&query=python
# Python-разработчик
# https://spb.hh.ru/
# Тинькофф
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76921562?from=vacancy_search_list&query=python
# Data-engeneer (Middle)
# https://spb.hh.ru/
# Платформа Больших Данных
# 250 000 – 300 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76925483?from=vacancy_search_list&query=python
# Data Scientist
# https://spb.hh.ru/
# 7RedLines
# 160 000 – 200 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77208642?from=vacancy_search_list&query=python
# Data Scientist middle+/Senior
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# 250 000 – 350 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77197403?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# SberTech
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76141435?from=vacancy_search_list&query=python
# Python Data Engineer (junior)
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/75719539?from=vacancy_search_list&query=python
# Программист Python (middle)
# https://spb.hh.ru/
# Pentestit
# 70 000 – 105 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77020122?from=vacancy_search_list&query=python
# Python (Django) Backend developer
# https://spb.hh.ru/
# evrone.ru
# до  400 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/71259333?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# ООО  Новые Системы
# 100 000 – 100 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76447915?from=vacancy_search_list&query=python
# Разработчик (Backend developer / Python)
# https://spb.hh.ru/
# ООО  Статус
# от  100 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77280737?from=vacancy_search_list&query=python
# Middle Python разработчик/Руководитель группы
# https://spb.hh.ru/
# ООО  Точка Зрения
# 110 000 – 160 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77324689?from=vacancy_search_list&query=python
# Python Developer
# https://spb.hh.ru/
# ООО  КомплИТех
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77284919?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# Holyweb
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77315663?from=vacancy_search_list&query=python
# Программист Python
# https://spb.hh.ru/
# ООО  WaveAccess
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77294601?from=vacancy_search_list&query=python
# Python Developer (Backend)
# https://spb.hh.ru/
# Samsung Research Russia
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77179552?from=vacancy_search_list&query=python
# Senior Python разработчик
# https://spb.hh.ru/
# ООО  24 часа ТВ
# от  300 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77244580?from=vacancy_search_list&query=python
# Python developer (remote)
# https://spb.hh.ru/
# LATOKEN
# от  1 000   USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76826004?from=vacancy_search_list&query=python
# Программист Python (Django)
# https://spb.hh.ru/
# Enjoypro
# 160 000 – 180 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76354970?from=vacancy_search_list&query=python
# Data Analyst
# https://spb.hh.ru/
# ООО  Б-рейн Тех
# 2 000 – 5 000  USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77329747?from=vacancy_search_list&query=python
# Data engineer (middle+)
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# до  350 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77193793?from=vacancy_search_list&query=python
# Python-разработчик
# https://spb.hh.ru/
# Тинькофф
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76921562?from=vacancy_search_list&query=python
# Data-engeneer (Middle)
# https://spb.hh.ru/
# Платформа Больших Данных
# 250 000 – 300 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76925483?from=vacancy_search_list&query=python
# Data Scientist
# https://spb.hh.ru/
# 7RedLines
# 160 000 – 200 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77208642?from=vacancy_search_list&query=python
# Data Scientist middle+/Senior
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# 250 000 – 350 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77197403?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# SberTech
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76141435?from=vacancy_search_list&query=python
# Python Data Engineer (junior)
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/75719539?from=vacancy_search_list&query=python
# Программист Python (middle)
# https://spb.hh.ru/
# Pentestit
# 70 000 – 105 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77020122?from=vacancy_search_list&query=python
# Python (Django) Backend developer
# https://spb.hh.ru/
# evrone.ru
# до  400 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/71259333?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# ООО  Новые Системы
# 100 000 – 100 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76447915?from=vacancy_search_list&query=python
# Разработчик (Backend developer / Python)
# https://spb.hh.ru/
# ООО  Статус
# от  100 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77280737?from=vacancy_search_list&query=python
# Middle Python разработчик/Руководитель группы
# https://spb.hh.ru/
# ООО  Точка Зрения
# 110 000 – 160 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77324689?from=vacancy_search_list&query=python
# Python Developer
# https://spb.hh.ru/
# ООО  КомплИТех
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77284919?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# Holyweb
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77315663?from=vacancy_search_list&query=python
# Программист Python
# https://spb.hh.ru/
# ООО  WaveAccess
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77294601?from=vacancy_search_list&query=python
# Python Developer (Backend)
# https://spb.hh.ru/
# Samsung Research Russia
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77179552?from=vacancy_search_list&query=python
# Senior Python разработчик
# https://spb.hh.ru/
# ООО  24 часа ТВ
# от  300 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77244580?from=vacancy_search_list&query=python
# Python developer (remote)
# https://spb.hh.ru/
# LATOKEN
# от  1 000   USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76826004?from=vacancy_search_list&query=python
# Программист Python (Django)
# https://spb.hh.ru/
# Enjoypro
# 160 000 – 180 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76354970?from=vacancy_search_list&query=python
# Data Analyst
# https://spb.hh.ru/
# ООО  Б-рейн Тех
# 2 000 – 5 000  USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77329747?from=vacancy_search_list&query=python
# Data engineer (middle+)
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# до  350 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77193793?from=vacancy_search_list&query=python
# Python-разработчик
# https://spb.hh.ru/
# Тинькофф
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76921562?from=vacancy_search_list&query=python
# Data-engeneer (Middle)
# https://spb.hh.ru/
# Платформа Больших Данных
# 250 000 – 300 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76925483?from=vacancy_search_list&query=python
# Data Scientist
# https://spb.hh.ru/
# 7RedLines
# 160 000 – 200 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77208642?from=vacancy_search_list&query=python
# Data Scientist middle+/Senior
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# 250 000 – 350 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77197403?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# SberTech
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76141435?from=vacancy_search_list&query=python
# Python Data Engineer (junior)
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/75719539?from=vacancy_search_list&query=python
# Программист Python (middle)
# https://spb.hh.ru/
# Pentestit
# 70 000 – 105 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77020122?from=vacancy_search_list&query=python
# Python (Django) Backend developer
# https://spb.hh.ru/
# evrone.ru
# до  400 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/71259333?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# ООО  Новые Системы
# 100 000 – 100 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76447915?from=vacancy_search_list&query=python
# Разработчик (Backend developer / Python)
# https://spb.hh.ru/
# ООО  Статус
# от  100 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77280737?from=vacancy_search_list&query=python
# Middle Python разработчик/Руководитель группы
# https://spb.hh.ru/
# ООО  Точка Зрения
# 110 000 – 160 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77324689?from=vacancy_search_list&query=python
# Python Developer
# https://spb.hh.ru/
# ООО  КомплИТех
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77284919?from=vacancy_search_list&query=python
# Python разработчик
# https://spb.hh.ru/
# Holyweb
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77315663?from=vacancy_search_list&query=python
# Программист Python
# https://spb.hh.ru/
# ООО  WaveAccess
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77294601?from=vacancy_search_list&query=python
# Python Developer (Backend)
# https://spb.hh.ru/
# Samsung Research Russia
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77179552?from=vacancy_search_list&query=python
# Senior Python разработчик
# https://spb.hh.ru/
# ООО  24 часа ТВ
# от  300 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77244580?from=vacancy_search_list&query=python
# Python developer (remote)
# https://spb.hh.ru/
# LATOKEN
# от  1 000   USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76826004?from=vacancy_search_list&query=python
# Программист Python (Django)
# https://spb.hh.ru/
# Enjoypro
# 160 000 – 180 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76354970?from=vacancy_search_list&query=python
# Data Analyst
# https://spb.hh.ru/
# ООО  Б-рейн Тех
# 2 000 – 5 000  USD
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77329747?from=vacancy_search_list&query=python
# Data engineer (middle+)
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# до  350 000   руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77193793?from=vacancy_search_list&query=python
# Python-разработчик
# https://spb.hh.ru/
# Тинькофф
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76921562?from=vacancy_search_list&query=python
# Data-engeneer (Middle)
# https://spb.hh.ru/
# Платформа Больших Данных
# 250 000 – 300 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/76925483?from=vacancy_search_list&query=python
# Data Scientist
# https://spb.hh.ru/
# 7RedLines
# 160 000 – 200 000  руб.
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77208642?from=vacancy_search_list&query=python
# Data Scientist middle+/Senior
# https://spb.hh.ru/
# ИП  Мамаева Ирина Анатольевна
# 250 000 – 350 000  руб.
# -------------------------------------------------------------
