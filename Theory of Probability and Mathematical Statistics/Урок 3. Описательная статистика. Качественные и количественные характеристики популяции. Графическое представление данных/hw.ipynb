# %% [markdown]
# ### 1. Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки. Сделать графическую интерпретацию данных, проанализовать выбросы, посчитать квартили и интерквартильное расстояние.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
salary = [100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 100]

# %%
#Среднее арифметическое
salary_mean = sum(salary) / len(salary)
print(f'{salary_mean} - среднее арифметическое')

#Среднее квадратическое отклонение
salary_std = 0

for el in salary:
  salary_std += pow(el-salary_mean, 2)

salary_std = salary_std / len(salary)
salary_std = pow(salary_std, 0.5)
print(f'{salary_std} - среднее квадратическое отклонение')

#Смещенная дисперсия
salary_dispersia_s = 0

for el in salary:
  salary_dispersia_s += pow(el-salary_mean, 2)

salary_dispersia_s = salary_dispersia_s / len(salary)
print(f'{salary_dispersia_s} - смещенная дисперсия')

#Несмещенная дисперсия
salary_dispersia = 0

for el in salary:
  salary_dispersia += pow(el-salary_mean, 2)

salary_dispersia = salary_dispersia / (len(salary) - 1)
print(f'{salary_dispersia} - несмещенная дисперсия')
# Out:
# 62.8 - среднее арифметическое
# 25.40393670280258 - среднее квадратическое отклонение
# 645.36 - смещенная дисперсия
# 679.3263157894737 - несмещенная дисперсия

# %%
# Построим ящик с усами 
sns.set_theme(style='whitegrid')
sns.boxplot(salary, orient='v')

# %% [markdown]
# Судя по графику выбросов не имеем

# %%
#графически отобразим данные
sns.histplot(salary)

# %%
#Квартили. (с пониманием проблем нет, поэтому посчитаю через функции)
q25 = np.quantile(salary, q=0.25)
q50 = np.quantile(salary, q=0.50)
q75 = np.quantile(salary, q=0.75)
print(f'{q25} - квартиль 25')
print(f'{q50} - квартиль 50 (медиана)')
print(f'{q75} - квартиль 75')
print(f'{q75 - q25} - интерквартильный размах')
# Out:
# 42.0 - квартиль 25
# 67.5 - квартиль 50 (медиана)
# 81.0 - квартиль 75
# 39.0 - интерквартильный размах

# %% [markdown]
# ### 2. В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %% [markdown]
# ![photo_2022-07-10_23-07-53.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 3. В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %%
#A=x, B=x, C=2x
#На факультете А
0.8*0.3*0.1
#На факультете В
0.2*0.7*0.1
#На факультете С
0.2*0.3*0.9
# Out:
# 0.054

# %% [markdown]
# ### 4. Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %%
detail_1 = 0.1
detail_2 = 0.2
detail_3 = 0.25

# %%
#Выйдут из строя все детали
detail_1 * detail_2 * detail_3
# Out:
# 0.005000000000000001

# %%
#Выйдет из строя хотя бы одна деталь
detail_1 + detail_2 + detail_3
# Out:
# 0.55

# %%
#Выйдут из строя только две детали
# 3 варианта выхода из строя: 1 и 2, 1 и 3, 2 и 3.
0.1*0.2 + 0.1*0.25 + 0.2*0.25
# Out:
# 0.095

# %%
#Выйдут из строя от одной до двух деталей
#одна делать
a = 0.1*(1-0.2)*(1-0.25) + (1-0.1)*0.2*(1-0.25) + (1-0.1)*(1-0.2)*0.25
#две детали
b = 0.1*0.2*(1-0.25) + 0.1*(1-0.2)*0.25 + (1-0.1)*0.2*0.25
#складываем, так как нам 1 или 2 детали интересуют
print(a+b)
# Out:
# 0.455
