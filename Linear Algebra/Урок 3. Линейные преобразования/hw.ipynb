# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

A = np.array([[-1, -6], [2, 6]])
w, v = np.linalg.eig(A)

print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89442719  0.83205029]
#  [ 0.4472136  -0.5547002 ]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ответ: любой вектор считает для него собственным

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Должно выполняться следующее условие:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Ответ: вектор (1,1) считается собственным вектором данного линейного оператора

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В расчетах получил:
# ![image.png](attachment:image.png)
# Ответ: не является собственным вектором линейного пространства
