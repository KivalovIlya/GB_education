# %% [markdown]
# ### 1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#доверительный интервал
left_border = 80 - 2*np.sqrt(80/256)
right_border = 80 + 2*np.sqrt(80/256)
print(f'({left_border}, {right_border})')
# Out:
# (78.8819660112501, 81.1180339887499)

# %% [markdown]
# ### 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
# ### Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %%
a = np.array([6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1])
a_mean = a.mean() #6.59
s = a.std(ddof=1) #0.4508017549014448

# %% [markdown]
# $$
# P \left(
# \overline{X} - t_{1 - \alpha/2, \: n - 1} \cdot \dfrac{\sigma_X}{\sqrt{n}}
# \leq M(X) \leq
# \overline{X} + t_{1 - \alpha/2, \: n - 1} \cdot \dfrac{\sigma_X}{\sqrt{n}}
# \right) = 1 - \alpha.
# $$

# %% [markdown]
# $$
# P \left(
# 6.59 - t_{1 - 0.95/2, \: 10 - 1} \cdot \dfrac{0.4508017549014448}{\sqrt{10}}
# \leq M(X) \leq
# 6.59 + t_{1 - 0.95/2, \: 10 - 1} \cdot \dfrac{0.4508017549014448}{\sqrt{10}}
# \right) = 1 - \alpha.
# $$

# %%
# Коэффициент Стьюдента: 2.2621571627409915
left_board = 6.59 - 2.2621571627409915*(0.4508017549014448/np.sqrt(10))
right_board = 6.59 + 2.2621571627409915*(0.4508017549014448/np.sqrt(10))
print(f'({left_board}, {right_board})')

# %% [markdown]
# Таким образом Х располагается в данном промежутке. Одно из значений (7.5) выходит за рамки

# %% [markdown]
# ### 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# Так и не смог ее решить и разобрать.
# Нашел в интернете решение похожей задачи.
# ![Снимок.PNG](data:image/png;base64,...)
# В целом все по решеню ясно, но как рассчитали критическую точку в этом моменте я не понял:
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ### 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
a = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
a_mean = a.mean() # 198.5
s = a.std(ddof=1) # 4.453463071962462

# %% [markdown]
# $$
# P \left(
# 198.5 - t_{1 - 0.99/2, \: 10 - 1} \cdot \dfrac{4.453463071962462}{\sqrt{10}}
# \leq M(X) \leq
# 198.5 + t_{1 - 0.99/2, \: 10 - 1} \cdot \dfrac{4.453463071962462}{\sqrt{10}}
# \right) = 1 - \alpha.
# $$

# %%
#Коэффициент Стьюдента: 3.2498355440153697

# %% [markdown]
# $$
# P \left(
# 198.5 - 3.2498355440153697 \cdot \dfrac{4.453463071962462}{\sqrt{10}}
# \leq M(X) \leq
# 198.5 + 3.2498355440153697 \cdot \dfrac{4.453463071962462}{\sqrt{10}}
# \right)
# $$

# %%
left_board = 198.5 - 3.2498355440153697*(4.453463071962462/np.sqrt(10))
right_board = 198.5 + 3.2498355440153697*(4.453463071962462/np.sqrt(10))
print(f'({left_board}, {right_board})')
# Out:
# (193.92322840036354, 203.07677159963646)

# %% [markdown]
# Значения из выборки входят в доверительный интервал 99%. Утверждение продавца верно.
