# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a)произведение матриц невозможно
# б)только AB возможно (итоговый размер 2x3)
# в)определены оба произведения (размер AB(8x8), размер BA(3х3))
# г)определены оба произведения (размер 4х4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
A = np.array([[1, -2], [3, 0]])
B = np.array([[4, -1], [0, 5]])

print(f'Сумма матриц A и B: \n{A + B}')
print(f'Произведение матриц A и B \n{A @ B}')
# Out:
# Сумма матриц A и B:
# [[ 5 -3]
#  [ 3  5]]
# Произведение матриц A и B
# [[  4 -11]
#  [ 12  -3]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[1, 7], [3, -6]])
B = np.array([[0, 5], [2, -1]])
C = np.array([[2, -4], [1, 1]])

print(3*A - 2*B + 4*C)
# Out:
# [[ 11  -5]
#  [  9 -12]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[4, 1], [5, -2], [2, 3]])

print(f'AAt: \n{A @ A.T}')
print(f'AtA: \n{A.T @ A}')
# Out:
# AAt:
# [[17 18 11]
#  [18 29  4]
#  [11  4 13]]
# AtA:
# [[45  0]
#  [ 0 14]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# не буду все таки изобретать велосипед, numpy хорошо справляется

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from numpy import linalg

# %% [markdown]
# а)sin(x)*sin(x) + cos(x)*cos(x)

# %% [markdown]
# б)

# %%
M = [[4, 2, 3], [0, 5, 1], [0, 0, 9]]
print(f'Определитель: {linalg.det(M)}')
# Out:
# Определитель: 180.0

# %% [markdown]
# в)

# %%
M = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(f'Определитель: {int(linalg.det(M))}')
# Out:
# Определитель: 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# а)16
# б)4
# в)8

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
M = np.array([[-2, 7, -3], [4, -14, 6], [-3, 7, 13]])
print(f'Определитель: {int(linalg.det(M))}')
# Out:
# Определитель: 0

# %% [markdown]
# Так как определитель матрицы равен нулю, то данная матрица считается вырожденной

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# а)

# %%
A = np.array([[1, 2, 3], [1, 1, 1], [2, 3, 4]])
print(f'Ранг матрицы: {linalg.matrix_rank(A)}')
# Out:
# Ранг матрицы: 2

# %% [markdown]
# б)

# %%
A = np.array([[0, 0, 2, 1], [0, 0, 2, 2], [0, 0, 4, 3], [2, 3, 5, 6]])
print(f'Ранг матрицы: {linalg.matrix_rank(A)}')
# Out:
# Ранг матрицы: 3
