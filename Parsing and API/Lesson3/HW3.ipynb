# %% [markdown]
# Вариант 1
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы получаем должность) с сайтов HH(обязательно) и/или Superjob(по желанию). Приложение должно анализировать несколько страниц сайта (также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     1. Наименование вакансии.
#     2. Предлагаемую зарплату (разносим в три поля: минимальная и максимальная и валюта. цифры        преобразуем к цифрам).
#     3.  Ссылку на саму вакансию.
#     4. Сайт, откуда собрана вакансия.
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas. Сохраните в json либо csv.

# %%
import requests
import lxml
from lxml import html
from bs4 import BeautifulSoup
import pandas as pd

pages = [1, 2, 3, 4, 5]
query = input('Enter the title: ').replace(' ', '+')
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/110.0'}
result_date = []


for page in pages:
    url = f'https://spb.hh.ru/search/vacancy?text={query}&page=1'
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, 'lxml')
    all_div_vacancy = soup.find_all('div', class_='vacancy-serp-item-body__main-info')
    for div in all_div_vacancy:
        vacancy_date = []
        vacancy_date.append(div.find('a', class_='serp-item__title').get('href'))
        vacancy_date.append(div.find('a', class_='serp-item__title').contents[0])
        vacancy_date.append('https://spb.hh.ru/')
        try:
            vacancy_date.append(''.join(div.find('a', class_='bloko-link bloko-link_kind-tertiary').contents))
        except:
            vacancy_date.append(' ')
        try:
            vacancy_date.append(''.join(div.find('span', class_='bloko-header-section-3').contents))
        except:
            vacancy_date.append(' ')  
        result_date.append(vacancy_date)
    
for el in result_date:
    for _ in el:
        print(_)
    print('-------------------------------------------------------------')
# Out:
# Enter the title: Data analyst
# https://spb.hh.ru/vacancy/68822135?from=vacancy_search_list&query=Data+analyst
# Data Analyst (финансовый мониторинг)
# https://spb.hh.ru/
# «РОСБАНК»
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/69583138?from=vacancy_search_list&query=Data+analyst
# Data Analyst
# https://spb.hh.ru/
# Лига Цифровой Экономики
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77223061?from=vacancy_search_list&query=Data+analyst
# Data аналитик/Аналитик BI
# https://spb.hh.ru/
# Авито: продажи
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77146730?from=vacancy_search_list&query=Data+analyst
# Data Analyst
# https://spb.hh.ru/
# INSITECH Development
#
# -------------------------------------------------------------
# https://spb.hh.ru/vacancy/77144005?from=vacancy_search_list&query=Data+analyst
# Data Analyst
# https://spb.hh.ru/
# ...
